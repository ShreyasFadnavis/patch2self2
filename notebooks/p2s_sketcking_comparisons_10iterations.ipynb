# %%
from dipy.io.image import load_nifti, save_nifti
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from warnings import warn
import time
from dipy.utils.optpkg import optional_package
from sklearn.utils.extmath import randomized_svd
import dipy.core.optimize as opt
import math

sklearn, has_sklearn, _ = optional_package('sklearn')
linear_model, _, _ = optional_package('sklearn.linear_model')

if not has_sklearn:
    w = "Scikit-Learn is required to denoise the data via Patch2Self."
    warn(w)
    

def _vol_split(train, vol_idx):
    """ Split the 3D volumes into the train and test set.

    Parameters
    ----------
    train : ndarray
        Array of all 3D patches flattened out to be 2D.

    vol_idx: int
        The volume number that needs to be held out for training.

    Returns
    --------
    cur_x : 2D-array (nvolumes*patch_size) x (nvoxels)
        Array of patches corresponding to all the volumes except for the
        held-out volume.

    y : 1D-array
        Array of patches corresponding to the volume that is used a target for
        denoising.
    """
    # Hold-out the target volume
    mask = np.zeros(train.shape[0])
    mask[vol_idx] = 1
    cur_x = train[mask == 0]
    cur_x = cur_x.reshape(((train.shape[0]-1)*train.shape[1],
                           train.shape[2]))

    # Center voxel of the selected block
    y = train[vol_idx, train.shape[1]//2, :]
    return cur_x, y

def count_sketch(matrixA, s):
    m, n = matrixA.shape
    matrixC = np.zeros([s, n])
    hashedIndices = np.random.choice(s, m, replace=True)
    # a m-by-1 {+1, -1} vector
    randSigns = np.random.choice(2, m, replace=True) * 2 - 1  
    
    # flip the signs of 50% rows of A
    matrixA = matrixA * randSigns.reshape(m, 1)  
    
    # this loop directly computes matrixC= S * matrixA
    for i in range(s):  
        idx = (hashedIndices == i)
        matrixC[i] = np.sum(matrixA[idx], 0)
    
    return matrixC[:, np.newaxis, :]


def _real_fft(matrixA):
    
    n_int = matrixA.shape[0]
    fft_mat = np.fft.fft(matrixA, n=None, axis=0) / np.sqrt(n_int)
    if n_int % 2 == 1:
        cutoff_int = int((n_int+1) / 2)
        idx_real_vec = list(range(1, cutoff_int))
        idx_imag_vec = list(range(cutoff_int, n_int))
    else:
        cutoff_int = int(n_int/2)
        idx_real_vec = list(range(1, cutoff_int))
        idx_imag_vec = list(range(cutoff_int+1, n_int))
    matrixC = fft_mat.real
    matrixC[idx_real_vec] *= np.sqrt(2)
    matrixC[idx_imag_vec] = fft_mat[idx_imag_vec].imag * np.sqrt(2)
    return matrixC[:, np.newaxis, :]

def deter_row_sample(matrixA, s):
    lev_scores = lev_exact(matrixA)
    idx_vec = np.argsort(lev_scores, axis=0)[::-1][range(s)]  # [lev_scores<0.003]
    matrixC = matrixA[idx_vec, :]
    return matrixC[:, np.newaxis, :]

def srft(matrixA, s):

    n_int = matrixA.shape[0]
    sign_vec = np.random.choice(2, n_int) * 2 - 1
    idx_vec = np.random.choice(n_int, s, replace=False)
    a_mat = sign_vec.reshape(n_int,1) * matrixA
    a_mat = _real_fft(matrixA)
    matrixC = matrixA[idx_vec] * np.sqrt(n_int / s)

    return matrixC[:, np.newaxis, :]

def lev_approx(matrixA, lev_sketch_type, lev_sketch_size=5):
    
    m, n = matrixA.shape
    s = int(n * lev_sketch_size)
    
    if lev_sketch_type == 'countsketch':
        matrixB = np.squeeze(count_sketch(matrixA, s))
        
    elif lev_sketch_type == 'srft':
        matrixB = np.squeeze(srft(matrixA, s))
        
    elif lev_sketch_type == 'uniform':
        idx_vec = np.random.choice(m, s, replace=False)
        matrixB = matrixA[idx_vec] * (m / s)
        print(matrixB.shape)
    
    elif lev_sketch_type == 'exact':
        matrixB = matrixA
    
    _, S, V = np.linalg.svd(matrixB, full_matrices=False)
    
    matrixT = V.T / S
    matrixY = np.dot(matrixA, matrixT)
    
    lev_vec = np.sum(matrixY ** 2, axis=1)
    return lev_vec

def ridge_lev_approx(matrixA, alpha):
    matrixA_alpha= np.concatenate((matrixA, np.sqrt(alpha)*np.identity(matrixA.shape[1])), axis=0)
    ridge_vec=lev_approx(matrixA_alpha)
    return ridge_vec[0:matrixA.shape[0]]

def row_sample(matrixA, s, prob_vec):
    m = matrixA.shape[0]
    prob_vec /= sum(prob_vec)
    idx_vec = np.random.choice(m, s, replace=False, p=prob_vec)
    scaling_vec = np.sqrt(s * prob_vec[idx_vec]) + 1e-10
    matrixC = matrixA[idx_vec] / scaling_vec.reshape(len(scaling_vec),1)
    return matrixC[:, np.newaxis, :]

def lev_exact(a_mat, low_rank=False):
    n_int = a_mat.shape[0]
    _ , _, v_mat = np.linalg.svd(a_mat.T, full_matrices=False)
    
    if low_rank:
        _, _, v_mat = randomized_svd(a_mat.T, 
                                     n_components=20,
                                     n_iter=5,
                                     random_state=None)
    lev_vec = np.sum(v_mat ** 2, axis=0)
    return lev_vec

def uniform_sampling(matrixA, s):
    m, n = matrixA.shape
    idx_vec = np.random.choice(m, s, replace=True)
    matrixC = matrixA[idx_vec]
    return matrixC[:, np.newaxis, :]

def sketch_data(matrixA, s, sketching_method, lev_sketch_type):
    
    if sketching_method == 'srft':
        return srft(matrixA, s)
    
    if sketching_method == 'uniform':
        return uniform_sampling(matrixA, s)
    
    if sketching_method == 'countsketch':
        return count_sketch(matrixA, s)
    
    if sketching_method == 'lev_deterministic':
        return deter_row_sample(matrixA, s)
    
    if sketching_method == 'leverage_scores':
        if lev_sketch_type == 'uniform':
            leverage_scores = lev_approx(matrixA, lev_sketch_type='uniform')
            return row_sample(matrixA, s, leverage_scores)
        
        elif lev_sketch_type == 'countsketch':
            leverage_scores = lev_approx(matrixA, lev_sketch_type='countsketch')
            return row_sample(matrixA, s, leverage_scores)
        
        elif lev_sketch_type == 'srft':
            leverage_scores = lev_approx(matrixA, lev_sketch_type='srft')
            return row_sample(matrixA, s, leverage_scores)
        
        elif lev_sketch_type == 'exact':
            leverage_scores = lev_exact(matrixA)
            return row_sample(matrixA, s, leverage_scores)

def _vol_denoise(train, sketched_train, vol_idx, 
                 model, data_shape, alpha):
    """ Denoise a single 3D volume using a train and test phase.

    Parameters
    ----------
    train : ndarray
        Array of all 3D patches flattened out to be 2D.

    vol_idx : int
        The volume number that needs to be held out for training.

    model : string, or initialized linear model object.
            This will determine the algorithm used to solve the set of linear
            equations underlying this model. If it is a string it needs to be
            one of the following: {'ols', 'ridge', 'lasso'}. Otherwise,
            it can be an object that inherits from
            `dipy.optimize.SKLearnLinearSolver` or an object with a similar
            interface from Scikit-Learn:
            `sklearn.linear_model.LinearRegression`,
            `sklearn.linear_model.Lasso` or `sklearn.linear_model.Ridge`
            and other objects that inherit from `sklearn.base.RegressorMixin`.
            Default: 'ridge'.

    data_shape : ndarray
        The 4D shape of noisy DWI data to be denoised.

    alpha : float, optional
        Regularization parameter only for ridge and lasso regression models.
        default: 1.0

    Returns
    --------
    model prediction : ndarray
        Denoised array of all 3D patches flattened out to be 2D corresponding
        to the held out volume `vol_idx`.

    """
    # To add a new model, use the following API
    # We adhere to the following options as they are used for comparisons
    if model.lower() == 'ols':
        model = linear_model.LinearRegression(copy_X=False)

    elif model.lower() == 'ridge':
        model = linear_model.Ridge(copy_X=False, alpha=alpha, solver='lsqr')

    elif model.lower() == 'lasso':
        model = linear_model.Lasso(copy_X=False, max_iter=50, alpha=alpha)

    elif (isinstance(model, opt.SKLearnLinearSolver) or
          has_sklearn and isinstance(model, sklearn.base.RegressorMixin)):
        model = model

    else:
        e_s = "The `solver` key-word argument needs to be: "
        e_s += "'ols', 'ridge', 'lasso' or a "
        e_s += "`dipy.optimize.SKLearnLinearSolver` object"
        raise ValueError(e_s)

    cur_x, y = _vol_split(train, vol_idx)
    r_cur_x, r_cur_y = _vol_split(sketched_train.T, vol_idx)
    
    model.fit(r_cur_x.T, r_cur_y.T)
    coefs = model.coef_

    return model.predict(cur_x.T).reshape(data_shape[0], data_shape[1],
                                          data_shape[2]), coefs

def _extract_3d_patches(arr, patch_radius):
    """ Extract 3D patches from 4D DWI data.

    Parameters
    ----------
    arr : ndarray
        The 4D noisy DWI data to be denoised.

    patch_radius : int or 1D array
        The radius of the local patch to be taken around each voxel (in
        voxels).

    Returns
    --------
    all_patches : ndarray
        All 3D patches flattened out to be 2D corresponding to the each 3D
        volume of the 4D DWI data.

    """
    if isinstance(patch_radius, int):
        patch_radius = np.ones(3, dtype=int) * patch_radius
    if len(patch_radius) != 3:
        raise ValueError("patch_radius should have length 3")
    else:
        patch_radius = np.asarray(patch_radius, dtype=int)
    patch_size = 2 * patch_radius + 1

    dim = arr.shape[-1]

    all_patches = []

    # loop around and find the 3D patch for each direction
    for i in range(patch_radius[0], arr.shape[0] -
                   patch_radius[0], 1):
        for j in range(patch_radius[1], arr.shape[1] -
                       patch_radius[1], 1):
            for k in range(patch_radius[2], arr.shape[2] -
                           patch_radius[2], 1):

                ix1 = i - patch_radius[0]
                ix2 = i + patch_radius[0] + 1
                jx1 = j - patch_radius[1]
                jx2 = j + patch_radius[1] + 1
                kx1 = k - patch_radius[2]
                kx2 = k + patch_radius[2] + 1

                X = arr[ix1:ix2, jx1:jx2,
                        kx1:kx2].reshape(np.prod(patch_size), dim)
                
                # Random projection on the X
                all_patches.append(X)

    return np.array(all_patches).T


def patch2self(data, bvals, patch_radius=[0, 0, 0], model='ridge',
               b0_threshold=50, out_dtype=None, alpha=1.0, 
               verbose=False, sketching_method='srft', sketch_size=2000, 
               lev_sketch_type='uniform'):
    
    """ Patch2Self Denoiser

    Parameters
    ----------
    data : ndarray
        The 4D noisy DWI data to be denoised.

    bvals : 1D array
        Array of the bvals from the DWI acquisition

    patch_radius : int or 1D array, optional
        The radius of the local patch to be taken around each voxel (in
        voxels). Default: 0 (denoise in blocks of 1x1x1 voxels).

    model : string, or initialized linear model object.
            This will determine the algorithm used to solve the set of linear
            equations underlying this model. If it is a string it needs to be
            one of the following: {'ols', 'ridge', 'lasso'}. Otherwise,
            it can be an object that inherits from
            `dipy.optimize.SKLearnLinearSolver` or an object with a similar
            interface from Scikit-Learn:
            `sklearn.linear_model.LinearRegression`,
            `sklearn.linear_model.Lasso` or `sklearn.linear_model.Ridge`
            and other objects that inherit from `sklearn.base.RegressorMixin`.
            Default: 'ridge'.

    b0_threshold : int, optional
        Threshold for considering volumes as b0.

    out_dtype : str or dtype, optional
        The dtype for the output array. Default: output has the same dtype as
        the input.

    alpha : float, optional
        Regularization parameter only for ridge regression model.
        default: 1.0

    verbose : bool, optional
        Show progress of Patch2Self and time taken.

    Returns
    --------
    denoised array : ndarray
        This is the denoised array of the same size as that of the input data,
        clipped to non-negative values.

    References
    ----------

    [Fadnavis20] S. Fadnavis, J. Batson, E. Garyfallidis, Patch2Self:
                    Denoising Diffusion MRI with Self-supervised Learning,
                    Advances in Neural Information Processing Systems 33 (2020)
    """
    patch_radius = np.asarray(patch_radius, dtype=np.int)

    if not data.ndim == 4:
        raise ValueError("Patch2Self can only denoise on 4D arrays.",
                         data.shape)

    if data.shape[3] < 10:
        warn("The intput data has less than 10 3D volumes. Patch2Self may not",
             "give denoising performance.")

    if out_dtype is None:
        out_dtype = data.dtype

    # We retain float64 precision, iff the input is in this precision:
    if data.dtype == np.float64:
        calc_dtype = np.float64

    # Otherwise, we'll calculate things in float32 (saving memory)
    else:
        calc_dtype = np.float32

    # Segregates volumes by b0 threshold
    b0_idx = np.argwhere(bvals <= b0_threshold)
    dwi_idx = np.argwhere(bvals > b0_threshold)

    data_b0s = np.squeeze(np.take(data, b0_idx, axis=3))
    data_dwi = np.squeeze(np.take(data, dwi_idx, axis=3))

    # create empty arrays
    denoised_b0s = np.empty((data_b0s.shape), dtype=calc_dtype)
    denoised_dwi = np.empty((data_dwi.shape), dtype=calc_dtype)

    denoised_arr = np.empty((data.shape), dtype=calc_dtype)

    if verbose is True:
        t1 = time.time()

    # Separate denoising for DWI volumes
    train_dwi = _extract_3d_patches(np.pad(data_dwi, ((patch_radius[0],
                                                       patch_radius[0]),
                                                      (patch_radius[1],
                                                       patch_radius[1]),
                                                      (patch_radius[2],
                                                       patch_radius[2]),
                                                      (0, 0)), mode='constant'),
                                    patch_radius=patch_radius)
    
    levs = lev_exact(np.squeeze(train_dwi).T)
    sketched_train_dwi = sketch_data(np.squeeze(train_dwi).T, 
                                     sketching_method=sketching_method, 
                                     s=sketch_size, lev_sketch_type=lev_sketch_type)
    
    print(sketched_train_dwi.shape)

    # Insert the separately denoised arrays into the respective empty arrays
    coef_list = []
    for vol_idx in range(60, 61):
        denoised_dwi[..., vol_idx] = _vol_denoise(train_dwi,
                                                  sketched_train_dwi,
                                                  vol_idx, model,
                                                  data_dwi.shape,
                                                  alpha=alpha)[0]
        coefs = _vol_denoise(train_dwi,
                             sketched_train_dwi,
                             vol_idx, model,
                             data_dwi.shape,
                             alpha=alpha)[1]
        coef_list.append(coefs)

        if verbose is True:
            print("Denoised DWI Volume: ", vol_idx)

    if verbose is True:
        t2 = time.time()
        print('Total time taken for Patch2Self: ', t2-t1, " seconds")

    if data_b0s.ndim == 3:
        denoised_arr[:, :, :, b0_idx[0][0]] = denoised_b0s
    else:
        for i, idx in enumerate(b0_idx):
            denoised_arr[:, :, :, idx[0]] = np.squeeze(denoised_b0s[..., i])

    for i, idx in enumerate(dwi_idx):
        denoised_arr[:, :, :, idx[0]] = np.squeeze(denoised_dwi[..., i])

    # clip out the negative values from the denoised output
    denoised_arr.clip(min=0, out=denoised_arr)

    return np.array(denoised_arr, dtype=out_dtype), coef_list

# %%
data, affine = load_nifti('dwi_corr.nii.gz')
bval = np.loadtxt('corr.bval')

# %%
from numpy import mean

list_sketch_size = [500, 1000, 5000, 10000, 20000, 30000, 40000, 50000, 
                    60000, 70000, 80000, 100000]#, 200000, 300000]
#                     , 400000,
#                     500000, 600000, 700000, 800000, 900000]
coef_list = []
sketch_name_list = []

for j in range(0, 10):
    print('This is ITERATION # ', j)

    for i in list_sketch_size:

        _, coefs_deter = patch2self(data, bval, verbose=True, model='ols', patch_radius=[0, 0, 0],
                                  b0_threshold=50, sketch_size=i, sketching_method='lev_deterministic')
        coef_list.append(coefs_deter)
        print('Deterministic Leverage - ', i)
        sketch_name_list.append('Deterministic Leverage')

        _, coefs_uni = patch2self(data, bval, verbose=True, model='ols', patch_radius=[0, 0, 0],
                                  b0_threshold=50, sketch_size=i, sketching_method='uniform')
        coef_list.append(coefs_uni)
        print('Uniform - ', i)
        sketch_name_list.append('Uniform')

        _, coefs_lev_exact = patch2self(data, bval, verbose=True, model='ols', patch_radius=[0, 0, 0],
                                        b0_threshold=50, sketch_size=i, 
                                        sketching_method='leverage_scores', 
                                        lev_sketch_type='exact')
        coef_list.append(coefs_lev_exact)
        print('Leverage Scores: Exact - ', i)
        sketch_name_list.append('Leverage Scores: Exact')

        _, coefs_cs = patch2self(data, bval, verbose=True, model='ols', patch_radius=[0, 0, 0],
                                 b0_threshold=50, sketch_size=i, sketching_method='countsketch')
        coef_list.append(coefs_cs)
        print('CS - ', i)
        sketch_name_list.append('Count Sketching')

        _, coefs_srft = patch2self(data, bval, verbose=True, model='ols', patch_radius=[0, 0, 0],
                                   b0_threshold=50, sketch_size=i, sketching_method='srft')
        coef_list.append(coefs_srft)
        print('SRFT - ', i)
        sketch_name_list.append('Subsampled Randomized Fourier Transform')
# Out:
# This is ITERATION #  0
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.5635712146759  seconds
# Deterministic Leverage -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  28.839262008666992  seconds
# Uniform -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.57374167442322  seconds
# Leverage Scores: Exact -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.380274772644043  seconds
# CS -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.19846820831299  seconds
# SRFT -  500
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.95524621009827  seconds
# Deterministic Leverage -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.973685026168823  seconds
# Uniform -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.12030100822449  seconds
# Leverage Scores: Exact -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  31.9836585521698  seconds
# CS -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.643341302871704  seconds
# SRFT -  1000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.32372236251831  seconds
# Deterministic Leverage -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.033995151519775  seconds
# Uniform -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.8775417804718  seconds
# Leverage Scores: Exact -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  40.79987025260925  seconds
# CS -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.520994901657104  seconds
# SRFT -  5000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.52183651924133  seconds
# Deterministic Leverage -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  27.329551935195923  seconds
# Uniform -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.75299096107483  seconds
# Leverage Scores: Exact -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.195069551467896  seconds
# CS -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.98849582672119  seconds
# SRFT -  10000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.79168248176575  seconds
# Deterministic Leverage -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.037250757217407  seconds
# Uniform -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.83652877807617  seconds
# Leverage Scores: Exact -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  63.50126767158508  seconds
# CS -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.2481164932251  seconds
# SRFT -  20000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.33539295196533  seconds
# Deterministic Leverage -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.846227169036865  seconds
# Uniform -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.09908723831177  seconds
# Leverage Scores: Exact -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  79.93250560760498  seconds
# CS -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.30141019821167  seconds
# SRFT -  30000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.583197593688965  seconds
# Deterministic Leverage -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.483474731445312  seconds
# Uniform -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.429001569747925  seconds
# Leverage Scores: Exact -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  97.69811725616455  seconds
# CS -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.36896467208862  seconds
# SRFT -  40000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.39433479309082  seconds
# Deterministic Leverage -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.254064798355103  seconds
# Uniform -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.9324836730957  seconds
# Leverage Scores: Exact -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  115.62114119529724  seconds
# CS -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.65444326400757  seconds
# SRFT -  50000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.12903070449829  seconds
# Deterministic Leverage -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.468740463256836  seconds
# Uniform -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.00311779975891  seconds
# Leverage Scores: Exact -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  131.98743152618408  seconds
# CS -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.1974151134491  seconds
# SRFT -  60000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.58001708984375  seconds
# Deterministic Leverage -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.582651615142822  seconds
# Uniform -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.403236389160156  seconds
# Leverage Scores: Exact -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  150.01387524604797  seconds
# CS -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.968024015426636  seconds
# SRFT -  70000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  51.54852867126465  seconds
# Deterministic Leverage -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  28.825300216674805  seconds
# Uniform -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.834662437438965  seconds
# Leverage Scores: Exact -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  169.3608934879303  seconds
# CS -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.19793152809143  seconds
# SRFT -  80000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.301695108413696  seconds
# Deterministic Leverage -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.62338352203369  seconds
# Uniform -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.370169162750244  seconds
# Leverage Scores: Exact -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  206.97784209251404  seconds
# CS -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.69146966934204  seconds
# SRFT -  100000
# This is ITERATION #  1
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.67070412635803  seconds
# Deterministic Leverage -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.59675645828247  seconds
# Uniform -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.63849425315857  seconds
# Leverage Scores: Exact -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.89380431175232  seconds
# CS -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.9935097694397  seconds
# SRFT -  500
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  46.024012327194214  seconds
# Deterministic Leverage -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.882659673690796  seconds
# Uniform -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.207077980041504  seconds
# Leverage Scores: Exact -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  31.841331481933594  seconds
# CS -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.11418318748474  seconds
# SRFT -  1000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.41963171958923  seconds
# Deterministic Leverage -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.54510498046875  seconds
# Uniform -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  43.47941303253174  seconds
# Leverage Scores: Exact -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  38.9629340171814  seconds
# CS -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.376044511795044  seconds
# SRFT -  5000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.67035937309265  seconds
# Deterministic Leverage -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  28.931474924087524  seconds
# Uniform -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  78.88841009140015  seconds
# Leverage Scores: Exact -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  66.08202385902405  seconds
# CS -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.60107684135437  seconds
# SRFT -  10000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  51.20610523223877  seconds
# Deterministic Leverage -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  27.746158599853516  seconds
# Uniform -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.18275570869446  seconds
# Leverage Scores: Exact -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  93.41798973083496  seconds
# CS -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.696961879730225  seconds
# SRFT -  20000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.13425827026367  seconds
# Deterministic Leverage -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  27.682342052459717  seconds
# Uniform -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  45.67038559913635  seconds
# Leverage Scores: Exact -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  106.39109992980957  seconds
# CS -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.49299740791321  seconds
# SRFT -  30000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  46.708009243011475  seconds
# Deterministic Leverage -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  27.625704050064087  seconds
# Uniform -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  46.067397117614746  seconds
# Leverage Scores: Exact -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  119.50844836235046  seconds
# CS -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.33495831489563  seconds
# SRFT -  40000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.1407573223114  seconds
# Deterministic Leverage -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  27.87300705909729  seconds
# Uniform -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  45.84423041343689  seconds
# Leverage Scores: Exact -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  150.69435048103333  seconds
# CS -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  38.93377876281738  seconds
# SRFT -  50000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  45.976834535598755  seconds
# Deterministic Leverage -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  28.49600386619568  seconds
# Uniform -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.246594190597534  seconds
# Leverage Scores: Exact -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  185.39896082878113  seconds
# CS -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.24428462982178  seconds
# SRFT -  60000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.18694758415222  seconds
# Deterministic Leverage -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  31.58150863647461  seconds
# Uniform -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  64.61426663398743  seconds
# Leverage Scores: Exact -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  190.2196958065033  seconds
# CS -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.85107970237732  seconds
# SRFT -  70000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  56.16421723365784  seconds
# Deterministic Leverage -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  31.10680890083313  seconds
# Uniform -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  53.9888072013855  seconds
# Leverage Scores: Exact -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  252.14837861061096  seconds
# CS -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.70042276382446  seconds
# SRFT -  80000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.76777791976929  seconds
# Deterministic Leverage -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.09568691253662  seconds
# Uniform -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.925124168395996  seconds
# Leverage Scores: Exact -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  229.41716527938843  seconds
# CS -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.1713387966156  seconds
# SRFT -  100000
# This is ITERATION #  2
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.95055055618286  seconds
# Deterministic Leverage -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.824590921401978  seconds
# Uniform -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.18349242210388  seconds
# Leverage Scores: Exact -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.672837018966675  seconds
# CS -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.2086398601532  seconds
# SRFT -  500
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.62661337852478  seconds
# Deterministic Leverage -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.564799547195435  seconds
# Uniform -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.9701201915741  seconds
# Leverage Scores: Exact -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  31.82094144821167  seconds
# CS -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  32.98781609535217  seconds
# SRFT -  1000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.05147099494934  seconds
# Deterministic Leverage -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.21841049194336  seconds
# Uniform -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.73815107345581  seconds
# Leverage Scores: Exact -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  38.680015563964844  seconds
# CS -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.40615630149841  seconds
# SRFT -  5000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.698490858078  seconds
# Deterministic Leverage -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.663562536239624  seconds
# Uniform -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.72949028015137  seconds
# Leverage Scores: Exact -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.641270875930786  seconds
# CS -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.67872381210327  seconds
# SRFT -  10000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.67682433128357  seconds
# Deterministic Leverage -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.869622945785522  seconds
# Uniform -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.0183207988739  seconds
# Leverage Scores: Exact -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  64.16596293449402  seconds
# CS -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.70205616950989  seconds
# SRFT -  20000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.808693408966064  seconds
# Deterministic Leverage -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.547807693481445  seconds
# Uniform -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.99397921562195  seconds
# Leverage Scores: Exact -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  81.29281044006348  seconds
# CS -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.39297652244568  seconds
# SRFT -  30000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.07749915122986  seconds
# Deterministic Leverage -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.750963926315308  seconds
# Uniform -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.91287899017334  seconds
# Leverage Scores: Exact -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  98.80464363098145  seconds
# CS -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.527262449264526  seconds
# SRFT -  40000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.67357325553894  seconds
# Deterministic Leverage -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.1402804851532  seconds
# Uniform -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.90038347244263  seconds
# Leverage Scores: Exact -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  116.10281348228455  seconds
# CS -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.874794006347656  seconds
# SRFT -  50000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.29187893867493  seconds
# Deterministic Leverage -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.613821268081665  seconds
# Uniform -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.081578731536865  seconds
# Leverage Scores: Exact -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  133.26694655418396  seconds
# CS -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.86082148551941  seconds
# SRFT -  60000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.37536406517029  seconds
# Deterministic Leverage -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.98935341835022  seconds
# Uniform -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.31714606285095  seconds
# Leverage Scores: Exact -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  151.82060551643372  seconds
# CS -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.43406867980957  seconds
# SRFT -  70000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  51.545061349868774  seconds
# Deterministic Leverage -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.417843341827393  seconds
# Uniform -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.14279127120972  seconds
# Leverage Scores: Exact -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  169.3547282218933  seconds
# CS -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.019410133361816  seconds
# SRFT -  80000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.39452290534973  seconds
# Deterministic Leverage -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.40139651298523  seconds
# Uniform -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.517645597457886  seconds
# Leverage Scores: Exact -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  203.5739917755127  seconds
# CS -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.59648275375366  seconds
# SRFT -  100000
# This is ITERATION #  3
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.953481912612915  seconds
# Deterministic Leverage -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.2359676361084  seconds
# Uniform -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.23410892486572  seconds
# Leverage Scores: Exact -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  31.33073592185974  seconds
# CS -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.143590211868286  seconds
# SRFT -  500
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.74990224838257  seconds
# Deterministic Leverage -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.87526273727417  seconds
# Uniform -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.53256058692932  seconds
# Leverage Scores: Exact -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  31.78136682510376  seconds
# CS -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.579458475112915  seconds
# SRFT -  1000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.19522428512573  seconds
# Deterministic Leverage -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  24.693495273590088  seconds
# Uniform -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.03774929046631  seconds
# Leverage Scores: Exact -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  39.443960428237915  seconds
# CS -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.96842694282532  seconds
# SRFT -  5000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.67464900016785  seconds
# Deterministic Leverage -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.811918020248413  seconds
# Uniform -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.51783466339111  seconds
# Leverage Scores: Exact -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  46.71535062789917  seconds
# CS -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.30288910865784  seconds
# SRFT -  10000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.21729588508606  seconds
# Deterministic Leverage -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  28.13305425643921  seconds
# Uniform -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.56255388259888  seconds
# Leverage Scores: Exact -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  64.33806204795837  seconds
# CS -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.276287317276  seconds
# SRFT -  20000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.2779905796051  seconds
# Deterministic Leverage -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.652067184448242  seconds
# Uniform -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.2645468711853  seconds
# Leverage Scores: Exact -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  81.48917984962463  seconds
# CS -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.50981068611145  seconds
# SRFT -  30000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.06747388839722  seconds
# Deterministic Leverage -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.87697172164917  seconds
# Uniform -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.00656223297119  seconds
# Leverage Scores: Exact -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  98.99339437484741  seconds
# CS -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  38.03036189079285  seconds
# SRFT -  40000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.91848540306091  seconds
# Deterministic Leverage -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.991683959960938  seconds
# Uniform -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  53.82841873168945  seconds
# Leverage Scores: Exact -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  117.14601373672485  seconds
# CS -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.024147748947144  seconds
# SRFT -  50000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.14733648300171  seconds
# Deterministic Leverage -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.985539197921753  seconds
# Uniform -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.32420563697815  seconds
# Leverage Scores: Exact -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  133.44224643707275  seconds
# CS -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.71338963508606  seconds
# SRFT -  60000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.226465702056885  seconds
# Deterministic Leverage -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.516675233840942  seconds
# Uniform -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  51.053714752197266  seconds
# Leverage Scores: Exact -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  152.22958374023438  seconds
# CS -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.70746207237244  seconds
# SRFT -  70000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.8583037853241  seconds
# Deterministic Leverage -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.677977323532104  seconds
# Uniform -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.78156852722168  seconds
# Leverage Scores: Exact -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  168.29050302505493  seconds
# CS -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.4094340801239  seconds
# SRFT -  80000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.19290280342102  seconds
# Deterministic Leverage -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.992653608322144  seconds
# Uniform -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  51.49453806877136  seconds
# Leverage Scores: Exact -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  204.33298802375793  seconds
# CS -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.000890254974365  seconds
# SRFT -  100000
# This is ITERATION #  4
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.28115653991699  seconds
# Deterministic Leverage -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.475613832473755  seconds
# Uniform -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.528891801834106  seconds
# Leverage Scores: Exact -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  28.763810873031616  seconds
# CS -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.32046031951904  seconds
# SRFT -  500
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.7837016582489  seconds
# Deterministic Leverage -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.833012104034424  seconds
# Uniform -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.98121190071106  seconds
# Leverage Scores: Exact -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  32.00086045265198  seconds
# CS -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.000075817108154  seconds
# SRFT -  1000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  45.42619872093201  seconds
# Deterministic Leverage -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.4961359500885  seconds
# Uniform -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.88095426559448  seconds
# Leverage Scores: Exact -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  39.4616494178772  seconds
# CS -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.92752289772034  seconds
# SRFT -  5000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.997600078582764  seconds
# Deterministic Leverage -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.750693321228027  seconds
# Uniform -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.035682916641235  seconds
# Leverage Scores: Exact -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.4193012714386  seconds
# CS -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.97042965888977  seconds
# SRFT -  10000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.37408208847046  seconds
# Deterministic Leverage -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.90552568435669  seconds
# Uniform -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.699491024017334  seconds
# Leverage Scores: Exact -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  64.12586045265198  seconds
# CS -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.90791630744934  seconds
# SRFT -  20000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.15104818344116  seconds
# Deterministic Leverage -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.69719696044922  seconds
# Uniform -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.16460704803467  seconds
# Leverage Scores: Exact -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  82.08690786361694  seconds
# CS -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.11773109436035  seconds
# SRFT -  30000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.902870178222656  seconds
# Deterministic Leverage -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.039796590805054  seconds
# Uniform -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.82097554206848  seconds
# Leverage Scores: Exact -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  99.19624209403992  seconds
# CS -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.17706751823425  seconds
# SRFT -  40000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.00001907348633  seconds
# Deterministic Leverage -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.361328601837158  seconds
# Uniform -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.709938049316406  seconds
# Leverage Scores: Exact -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  115.92526602745056  seconds
# CS -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.9905571937561  seconds
# SRFT -  50000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.62891697883606  seconds
# Deterministic Leverage -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.376590728759766  seconds
# Uniform -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.4273784160614  seconds
# Leverage Scores: Exact -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  134.09479808807373  seconds
# CS -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.728344440460205  seconds
# SRFT -  60000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.69266223907471  seconds
# Deterministic Leverage -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.599151611328125  seconds
# Uniform -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.54274582862854  seconds
# Leverage Scores: Exact -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  151.73233675956726  seconds
# CS -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.04122042655945  seconds
# SRFT -  70000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.7920982837677  seconds
# Deterministic Leverage -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  28.714138507843018  seconds
# Uniform -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.563624143600464  seconds
# Leverage Scores: Exact -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  169.7239305973053  seconds
# CS -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.13529562950134  seconds
# SRFT -  80000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.8359580039978  seconds
# Deterministic Leverage -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.985037803649902  seconds
# Uniform -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.33905506134033  seconds
# Leverage Scores: Exact -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  217.7370789051056  seconds
# CS -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.368659257888794  seconds
# SRFT -  100000
# This is ITERATION #  5
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.01443362236023  seconds
# Deterministic Leverage -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.729510068893433  seconds
# Uniform -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.81953477859497  seconds
# Leverage Scores: Exact -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  31.272759199142456  seconds
# CS -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.26465439796448  seconds
# SRFT -  500
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.10676622390747  seconds
# Deterministic Leverage -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.55432677268982  seconds
# Uniform -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.775378942489624  seconds
# Leverage Scores: Exact -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  32.41331434249878  seconds
# CS -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.43398308753967  seconds
# SRFT -  1000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.15743684768677  seconds
# Deterministic Leverage -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.011759281158447  seconds
# Uniform -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.07325744628906  seconds
# Leverage Scores: Exact -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  39.270817041397095  seconds
# CS -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.266265630722046  seconds
# SRFT -  5000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.35473275184631  seconds
# Deterministic Leverage -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.55183243751526  seconds
# Uniform -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.66335701942444  seconds
# Leverage Scores: Exact -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.240553855895996  seconds
# CS -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.63475036621094  seconds
# SRFT -  10000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.196619510650635  seconds
# Deterministic Leverage -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.968267917633057  seconds
# Uniform -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.471932888031006  seconds
# Leverage Scores: Exact -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  65.10574698448181  seconds
# CS -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  34.879074573516846  seconds
# SRFT -  20000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.73417282104492  seconds
# Deterministic Leverage -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.594974517822266  seconds
# Uniform -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.80568981170654  seconds
# Leverage Scores: Exact -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  82.06969428062439  seconds
# CS -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.97465991973877  seconds
# SRFT -  30000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.55218958854675  seconds
# Deterministic Leverage -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.281282901763916  seconds
# Uniform -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.56453037261963  seconds
# Leverage Scores: Exact -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  98.71101069450378  seconds
# CS -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.6477267742157  seconds
# SRFT -  40000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.47942638397217  seconds
# Deterministic Leverage -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  31.203718662261963  seconds
# Uniform -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.914127826690674  seconds
# Leverage Scores: Exact -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  117.1313681602478  seconds
# CS -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.16454362869263  seconds
# SRFT -  50000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  52.20329213142395  seconds
# Deterministic Leverage -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.105817556381226  seconds
# Uniform -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  51.344783544540405  seconds
# Leverage Scores: Exact -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  134.8287751674652  seconds
# CS -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.16226267814636  seconds
# SRFT -  60000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.984384298324585  seconds
# Deterministic Leverage -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.567763328552246  seconds
# Uniform -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.68289852142334  seconds
# Leverage Scores: Exact -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  151.419819355011  seconds
# CS -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.88461208343506  seconds
# SRFT -  70000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.97692632675171  seconds
# Deterministic Leverage -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.972055435180664  seconds
# Uniform -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.978172063827515  seconds
# Leverage Scores: Exact -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  168.63389539718628  seconds
# CS -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.74943733215332  seconds
# SRFT -  80000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.54486536979675  seconds
# Deterministic Leverage -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.496891975402832  seconds
# Uniform -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.802204608917236  seconds
# Leverage Scores: Exact -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  203.88838171958923  seconds
# CS -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.742748975753784  seconds
# SRFT -  100000
# This is ITERATION #  6
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.119510650634766  seconds
# Deterministic Leverage -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.9426007270813  seconds
# Uniform -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.21897029876709  seconds
# Leverage Scores: Exact -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  31.0326189994812  seconds
# CS -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  34.51520133018494  seconds
# SRFT -  500
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.31730008125305  seconds
# Deterministic Leverage -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.766737699508667  seconds
# Uniform -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.957167625427246  seconds
# Leverage Scores: Exact -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  32.404635429382324  seconds
# CS -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.584065198898315  seconds
# SRFT -  1000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.30432915687561  seconds
# Deterministic Leverage -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.90926456451416  seconds
# Uniform -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.264914751052856  seconds
# Leverage Scores: Exact -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  39.310203075408936  seconds
# CS -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.58880066871643  seconds
# SRFT -  5000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.81699228286743  seconds
# Deterministic Leverage -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.68955659866333  seconds
# Uniform -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.2677960395813  seconds
# Leverage Scores: Exact -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.712993144989014  seconds
# CS -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.5457124710083  seconds
# SRFT -  10000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.03232288360596  seconds
# Deterministic Leverage -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.738229751586914  seconds
# Uniform -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.043482303619385  seconds
# Leverage Scores: Exact -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  62.33039736747742  seconds
# CS -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.17769646644592  seconds
# SRFT -  20000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.66290211677551  seconds
# Deterministic Leverage -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.262229681015015  seconds
# Uniform -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.91900706291199  seconds
# Leverage Scores: Exact -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  81.74914884567261  seconds
# CS -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.81353259086609  seconds
# SRFT -  30000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.10902380943298  seconds
# Deterministic Leverage -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# ...
# SRFT -  70000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.83392524719238  seconds
# Deterministic Leverage -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.380988836288452  seconds
# Uniform -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.67492079734802  seconds
# Leverage Scores: Exact -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  168.4823911190033  seconds
# CS -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.68785262107849  seconds
# SRFT -  80000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.69064950942993  seconds
# Deterministic Leverage -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.786225080490112  seconds
# Uniform -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.68502473831177  seconds
# Leverage Scores: Exact -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  204.40059280395508  seconds
# CS -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.293553590774536  seconds
# SRFT -  100000
# This is ITERATION #  8
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.75091791152954  seconds
# Deterministic Leverage -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.07434344291687  seconds
# Uniform -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.490943908691406  seconds
# Leverage Scores: Exact -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.915069818496704  seconds
# CS -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.30075240135193  seconds
# SRFT -  500
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.66205549240112  seconds
# Deterministic Leverage -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  28.532551527023315  seconds
# Uniform -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.05220913887024  seconds
# Leverage Scores: Exact -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  32.66071391105652  seconds
# CS -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.24416160583496  seconds
# SRFT -  1000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.22046756744385  seconds
# Deterministic Leverage -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.07638168334961  seconds
# Uniform -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.86451864242554  seconds
# Leverage Scores: Exact -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  39.20084595680237  seconds
# CS -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.027989864349365  seconds
# SRFT -  5000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.20016598701477  seconds
# Deterministic Leverage -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.788992404937744  seconds
# Uniform -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.836698055267334  seconds
# Leverage Scores: Exact -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.25828170776367  seconds
# CS -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.735336780548096  seconds
# SRFT -  10000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.97211837768555  seconds
# Deterministic Leverage -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.84449076652527  seconds
# Uniform -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.74617600440979  seconds
# Leverage Scores: Exact -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  64.00028252601624  seconds
# CS -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.80462694168091  seconds
# SRFT -  20000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.517516136169434  seconds
# Deterministic Leverage -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.86279010772705  seconds
# Uniform -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.14081382751465  seconds
# Leverage Scores: Exact -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  81.9957230091095  seconds
# CS -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.00141358375549  seconds
# SRFT -  30000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.981210470199585  seconds
# Deterministic Leverage -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.13057851791382  seconds
# Uniform -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.22684097290039  seconds
# Leverage Scores: Exact -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  98.85008645057678  seconds
# CS -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.65719652175903  seconds
# SRFT -  40000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.982581615448  seconds
# Deterministic Leverage -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.442392826080322  seconds
# Uniform -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.397767066955566  seconds
# Leverage Scores: Exact -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  116.8700647354126  seconds
# CS -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  35.92062854766846  seconds
# SRFT -  50000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.652889251708984  seconds
# Deterministic Leverage -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.301801204681396  seconds
# Uniform -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  51.0303909778595  seconds
# Leverage Scores: Exact -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  134.23636317253113  seconds
# CS -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.53376054763794  seconds
# SRFT -  60000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  51.04476881027222  seconds
# Deterministic Leverage -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.62421941757202  seconds
# Uniform -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.85395574569702  seconds
# Leverage Scores: Exact -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  152.4800124168396  seconds
# CS -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.48602485656738  seconds
# SRFT -  70000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.700156450271606  seconds
# Deterministic Leverage -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.33002257347107  seconds
# Uniform -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.59546518325806  seconds
# Leverage Scores: Exact -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  168.59504199028015  seconds
# CS -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.95610976219177  seconds
# SRFT -  80000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.57241368293762  seconds
# Deterministic Leverage -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  31.16933298110962  seconds
# Uniform -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.47606611251831  seconds
# Leverage Scores: Exact -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  204.11389803886414  seconds
# CS -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.70287251472473  seconds
# SRFT -  100000
# This is ITERATION #  9
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.13383603096008  seconds
# Deterministic Leverage -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.506011962890625  seconds
# Uniform -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.93022441864014  seconds
# Leverage Scores: Exact -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.99089288711548  seconds
# CS -  500
# (500, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.196921825408936  seconds
# SRFT -  500
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.88786482810974  seconds
# Deterministic Leverage -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.461560249328613  seconds
# Uniform -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.79331612586975  seconds
# Leverage Scores: Exact -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  31.517310857772827  seconds
# CS -  1000
# (1000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.15228223800659  seconds
# SRFT -  1000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.523520708084106  seconds
# Deterministic Leverage -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.51579737663269  seconds
# Uniform -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.98740243911743  seconds
# Leverage Scores: Exact -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.47874975204468  seconds
# CS -  5000
# (5000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.80579233169556  seconds
# SRFT -  5000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.964377880096436  seconds
# Deterministic Leverage -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.9301335811615  seconds
# Uniform -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.9555025100708  seconds
# Leverage Scores: Exact -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  46.01686978340149  seconds
# CS -  10000
# (10000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.74441885948181  seconds
# SRFT -  10000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.2597541809082  seconds
# Deterministic Leverage -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.785994291305542  seconds
# Uniform -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.253008127212524  seconds
# Leverage Scores: Exact -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  64.27541470527649  seconds
# CS -  20000
# (20000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.7708625793457  seconds
# SRFT -  20000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.2591347694397  seconds
# Deterministic Leverage -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.894334316253662  seconds
# Uniform -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.86949419975281  seconds
# Leverage Scores: Exact -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  82.21107220649719  seconds
# CS -  30000
# (30000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.555649518966675  seconds
# SRFT -  30000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.99185299873352  seconds
# Deterministic Leverage -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.602742433547974  seconds
# Uniform -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.625107288360596  seconds
# Leverage Scores: Exact -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  99.83798933029175  seconds
# CS -  40000
# (40000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.640340089797974  seconds
# SRFT -  40000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.918113470077515  seconds
# Deterministic Leverage -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.66113042831421  seconds
# Uniform -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.074366092681885  seconds
# Leverage Scores: Exact -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  116.04407143592834  seconds
# CS -  50000
# (50000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.46039533615112  seconds
# SRFT -  50000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  47.4347608089447  seconds
# Deterministic Leverage -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.710516214370728  seconds
# Uniform -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  49.668800354003906  seconds
# Leverage Scores: Exact -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  134.02157711982727  seconds
# CS -  60000
# (60000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.66191101074219  seconds
# SRFT -  60000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  48.11298680305481  seconds
# Deterministic Leverage -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  29.669674158096313  seconds
# Uniform -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.25607872009277  seconds
# Leverage Scores: Exact -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  151.97144174575806  seconds
# CS -  70000
# (70000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.77483773231506  seconds
# SRFT -  70000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.52531290054321  seconds
# Deterministic Leverage -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.835914850234985  seconds
# Uniform -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  51.19851899147034  seconds
# Leverage Scores: Exact -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  169.9057331085205  seconds
# CS -  80000
# (80000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  36.359073638916016  seconds
# SRFT -  80000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.6884400844574  seconds
# Deterministic Leverage -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  30.238851070404053  seconds
# Uniform -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  50.81406879425049  seconds
# Leverage Scores: Exact -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  205.58132982254028  seconds
# CS -  100000
# (100000, 1, 64)
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  37.756975412368774  seconds
# SRFT -  100000

# %%
from dipy.io.image import load_nifti, save_nifti
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from warnings import warn
import time
from dipy.utils.optpkg import optional_package
import dipy.core.optimize as opt
import math

sklearn, has_sklearn, _ = optional_package('sklearn')
linear_model, _, _ = optional_package('sklearn.linear_model')

if not has_sklearn:
    w = "Scikit-Learn is required to denoise the data via Patch2Self."
    warn(w)
    

def _vol_split(train, vol_idx):
    """ Split the 3D volumes into the train and test set.

    Parameters
    ----------
    train : ndarray
        Array of all 3D patches flattened out to be 2D.

    vol_idx: int
        The volume number that needs to be held out for training.

    Returns
    --------
    cur_x : 2D-array (nvolumes*patch_size) x (nvoxels)
        Array of patches corresponding to all the volumes except for the
        held-out volume.

    y : 1D-array
        Array of patches corresponding to the volume that is used a target for
        denoising.
    """
    # Hold-out the target volume
    mask = np.zeros(train.shape[0])
    mask[vol_idx] = 1
    cur_x = train[mask == 0]
    cur_x = cur_x.reshape(((train.shape[0]-1)*train.shape[1],
                           train.shape[2]))

    # Center voxel of the selected block
    y = train[vol_idx, train.shape[1]//2, :]
    return cur_x, y

def count_sketch(matrixA, s):
    m, n = matrixA.shape
    matrixC = np.zeros([s, n])
    hashedIndices = np.random.choice(s, m, replace=True)
    # a m-by-1 {+1, -1} vector
    randSigns = np.random.choice(2, m, replace=True) * 2 - 1  
    
    # flip the signs of 50% rows of A
    matrixA = matrixA * randSigns.reshape(m, 1)  
    
    # this loop directly computes matrixC= S * matrixA
    for i in range(s):  
        idx = (hashedIndices == i)
        matrixC[i] = np.sum(matrixA[idx], 0)
    
    return matrixC[:, np.newaxis, :]


def _real_fft(matrixA):
    
    n_int = matrixA.shape[0]
    fft_mat = np.fft.fft(matrixA, n=None, axis=0) / np.sqrt(n_int)
    if n_int % 2 == 1:
        cutoff_int = int((n_int+1) / 2)
        idx_real_vec = list(range(1, cutoff_int))
        idx_imag_vec = list(range(cutoff_int, n_int))
    else:
        cutoff_int = int(n_int/2)
        idx_real_vec = list(range(1, cutoff_int))
        idx_imag_vec = list(range(cutoff_int+1, n_int))
    matrixC = fft_mat.real
    matrixC[idx_real_vec] *= np.sqrt(2)
    matrixC[idx_imag_vec] = fft_mat[idx_imag_vec].imag * np.sqrt(2)
    return matrixC[:, np.newaxis, :]


def srft(matrixA, s):

    n_int = matrixA.shape[0]
    sign_vec = np.random.choice(2, n_int) * 2 - 1
    idx_vec = np.random.choice(n_int, s, replace=False)
    a_mat = sign_vec.reshape(n_int,1) * matrixA
    a_mat = _real_fft(matrixA)
    matrixC = matrixA[idx_vec] * np.sqrt(n_int / s)

    return matrixC[:, np.newaxis, :]

def lev_approx(matrixA, lev_sketch_size=5, lev_sketch_type='uniform'):
    m, n = matrixA.shape
    s = int(n * lev_sketch_size)
    
    if lev_sketch_type == 'countsketch':
        matrixB = count_sketch(matrixA, s)
        
    elif lev_sketch_type == 'srft':
        matrixB = srft(matrixA, s)
        
    elif lev_sketch_type == 'uniform':
        idx_vec = np.random.choice(m, s, replace=False)
        matrixB = matrixA[idx_vec] * (m / s)
        
    _, S, V = np.linalg.svd(matrixB, full_matrices=False)
    
    matrixT = V.T / S
    matrixY = np.dot(matrixA, matrixT)
    
    lev_vec = np.sum(matrixY ** 2, axis=1)
    return lev_vec

def ridge_lev_approx(matrixA, alpha):
    matrixA_alpha= np.concatenate((matrixA, np.sqrt(alpha)*np.identity(matrixA.shape[1])), axis=0)
    ridge_vec=lev_approx(matrixA_alpha)
    return ridge_vec[0:matrixA.shape[0]]

def row_sample(matrixA, s, prob_vec):
    m = matrixA.shape[0]
    prob_vec /= sum(prob_vec)
    idx_vec = np.random.choice(m, s, replace=False, p=prob_vec)
    scaling_vec = np.sqrt(s * prob_vec[idx_vec]) + 1e-10
    matrixC = matrixA[idx_vec] / scaling_vec.reshape(len(scaling_vec),1)
    return matrixC[:, np.newaxis, :]

def sketch_data(matrixA, s, sketching_method):
    
    if sketching_method == 'srft':
        return srft(matrixA, s)
    
    if sketching_method == 'countsketch':
        print(count_sketch(matrixA, s).shape)
        return count_sketch(matrixA, s)
    
    if sketching_method == 'leverage_scores':
        leverage_scores = lev_approx(matrixA)
        print(row_sample(matrixA, s, leverage_scores).shape)
        return row_sample(matrixA, s, leverage_scores)


def _vol_denoise(train, sketched_train, vol_idx, 
                 model, data_shape, alpha):
    """ Denoise a single 3D volume using a train and test phase.

    Parameters
    ----------
    train : ndarray
        Array of all 3D patches flattened out to be 2D.

    vol_idx : int
        The volume number that needs to be held out for training.

    model : string, or initialized linear model object.
            This will determine the algorithm used to solve the set of linear
            equations underlying this model. If it is a string it needs to be
            one of the following: {'ols', 'ridge', 'lasso'}. Otherwise,
            it can be an object that inherits from
            `dipy.optimize.SKLearnLinearSolver` or an object with a similar
            interface from Scikit-Learn:
            `sklearn.linear_model.LinearRegression`,
            `sklearn.linear_model.Lasso` or `sklearn.linear_model.Ridge`
            and other objects that inherit from `sklearn.base.RegressorMixin`.
            Default: 'ridge'.

    data_shape : ndarray
        The 4D shape of noisy DWI data to be denoised.

    alpha : float, optional
        Regularization parameter only for ridge and lasso regression models.
        default: 1.0

    Returns
    --------
    model prediction : ndarray
        Denoised array of all 3D patches flattened out to be 2D corresponding
        to the held out volume `vol_idx`.

    """
    # To add a new model, use the following API
    # We adhere to the following options as they are used for comparisons
    if model.lower() == 'ols':
        model = linear_model.LinearRegression(copy_X=False)

    elif model.lower() == 'ridge':
        model = linear_model.Ridge(copy_X=False, alpha=alpha, solver='lsqr')

    elif model.lower() == 'lasso':
        model = linear_model.Lasso(copy_X=False, max_iter=50, alpha=alpha)

    elif (isinstance(model, opt.SKLearnLinearSolver) or
          has_sklearn and isinstance(model, sklearn.base.RegressorMixin)):
        model = model

    else:
        e_s = "The `solver` key-word argument needs to be: "
        e_s += "'ols', 'ridge', 'lasso' or a "
        e_s += "`dipy.optimize.SKLearnLinearSolver` object"
        raise ValueError(e_s)

    cur_x, y = _vol_split(train, vol_idx)
    r_cur_x, r_cur_y = _vol_split(sketched_train.T, vol_idx)
    
    model.fit(cur_x.T, y.T)
    coefs = model.coef_

    return model.predict(cur_x.T).reshape(data_shape[0], data_shape[1],
                                          data_shape[2]), coefs

def _extract_3d_patches(arr, patch_radius):
    """ Extract 3D patches from 4D DWI data.

    Parameters
    ----------
    arr : ndarray
        The 4D noisy DWI data to be denoised.

    patch_radius : int or 1D array
        The radius of the local patch to be taken around each voxel (in
        voxels).

    Returns
    --------
    all_patches : ndarray
        All 3D patches flattened out to be 2D corresponding to the each 3D
        volume of the 4D DWI data.

    """
    if isinstance(patch_radius, int):
        patch_radius = np.ones(3, dtype=int) * patch_radius
    if len(patch_radius) != 3:
        raise ValueError("patch_radius should have length 3")
    else:
        patch_radius = np.asarray(patch_radius, dtype=int)
    patch_size = 2 * patch_radius + 1

    dim = arr.shape[-1]

    all_patches = []

    # loop around and find the 3D patch for each direction
    for i in range(patch_radius[0], arr.shape[0] -
                   patch_radius[0], 1):
        for j in range(patch_radius[1], arr.shape[1] -
                       patch_radius[1], 1):
            for k in range(patch_radius[2], arr.shape[2] -
                           patch_radius[2], 1):

                ix1 = i - patch_radius[0]
                ix2 = i + patch_radius[0] + 1
                jx1 = j - patch_radius[1]
                jx2 = j + patch_radius[1] + 1
                kx1 = k - patch_radius[2]
                kx2 = k + patch_radius[2] + 1

                X = arr[ix1:ix2, jx1:jx2,
                        kx1:kx2].reshape(np.prod(patch_size), dim)
                
                # Random projection on the X
                all_patches.append(X)

    return np.array(all_patches).T


def patch2self(data, bvals, patch_radius=[0, 0, 0], model='ridge',
               b0_threshold=50, out_dtype=None, alpha=1.0, 
               verbose=False, sketching_method='srft', sketch_size=2000):
    """ Patch2Self Denoiser

    Parameters
    ----------
    data : ndarray
        The 4D noisy DWI data to be denoised.

    bvals : 1D array
        Array of the bvals from the DWI acquisition

    patch_radius : int or 1D array, optional
        The radius of the local patch to be taken around each voxel (in
        voxels). Default: 0 (denoise in blocks of 1x1x1 voxels).

    model : string, or initialized linear model object.
            This will determine the algorithm used to solve the set of linear
            equations underlying this model. If it is a string it needs to be
            one of the following: {'ols', 'ridge', 'lasso'}. Otherwise,
            it can be an object that inherits from
            `dipy.optimize.SKLearnLinearSolver` or an object with a similar
            interface from Scikit-Learn:
            `sklearn.linear_model.LinearRegression`,
            `sklearn.linear_model.Lasso` or `sklearn.linear_model.Ridge`
            and other objects that inherit from `sklearn.base.RegressorMixin`.
            Default: 'ridge'.

    b0_threshold : int, optional
        Threshold for considering volumes as b0.

    out_dtype : str or dtype, optional
        The dtype for the output array. Default: output has the same dtype as
        the input.

    alpha : float, optional
        Regularization parameter only for ridge regression model.
        default: 1.0

    verbose : bool, optional
        Show progress of Patch2Self and time taken.

    Returns
    --------
    denoised array : ndarray
        This is the denoised array of the same size as that of the input data,
        clipped to non-negative values.

    References
    ----------

    [Fadnavis20] S. Fadnavis, J. Batson, E. Garyfallidis, Patch2Self:
                    Denoising Diffusion MRI with Self-supervised Learning,
                    Advances in Neural Information Processing Systems 33 (2020)
    """
    patch_radius = np.asarray(patch_radius, dtype=np.int)

    if not data.ndim == 4:
        raise ValueError("Patch2Self can only denoise on 4D arrays.",
                         data.shape)

    if data.shape[3] < 10:
        warn("The intput data has less than 10 3D volumes. Patch2Self may not",
             "give denoising performance.")

    if out_dtype is None:
        out_dtype = data.dtype

    # We retain float64 precision, iff the input is in this precision:
    if data.dtype == np.float64:
        calc_dtype = np.float64

    # Otherwise, we'll calculate things in float32 (saving memory)
    else:
        calc_dtype = np.float32

    # Segregates volumes by b0 threshold
    b0_idx = np.argwhere(bvals <= b0_threshold)
    dwi_idx = np.argwhere(bvals > b0_threshold)

    data_b0s = np.squeeze(np.take(data, b0_idx, axis=3))
    data_dwi = np.squeeze(np.take(data, dwi_idx, axis=3))

    # create empty arrays
    denoised_b0s = np.empty((data_b0s.shape), dtype=calc_dtype)
    denoised_dwi = np.empty((data_dwi.shape), dtype=calc_dtype)

    denoised_arr = np.empty((data.shape), dtype=calc_dtype)

    if verbose is True:
        t1 = time.time()

    # Separate denoising for DWI volumes
    train_dwi = _extract_3d_patches(np.pad(data_dwi, ((patch_radius[0],
                                                       patch_radius[0]),
                                                      (patch_radius[1],
                                                       patch_radius[1]),
                                                      (patch_radius[2],
                                                       patch_radius[2]),
                                                      (0, 0)), mode='constant'),
                                    patch_radius=patch_radius)
    
    sketched_train_dwi = sketch_data(np.squeeze(train_dwi).T, 
                                     sketching_method=sketching_method, 
                                     s=sketch_size)
    

    # Insert the separately denoised arrays into the respective empty arrays
    coef_list = []
    for vol_idx in range(60, 61):
        denoised_dwi[..., vol_idx] = _vol_denoise(train_dwi,
                                                  sketched_train_dwi,
                                                  vol_idx, model,
                                                  data_dwi.shape,
                                                  alpha=alpha)[0]
        coefs = _vol_denoise(train_dwi,
                             sketched_train_dwi,
                             vol_idx, model,
                             data_dwi.shape,
                             alpha=alpha)[1]
        coef_list.append(coefs)

        if verbose is True:
            print("Denoised DWI Volume: ", vol_idx)

    if verbose is True:
        t2 = time.time()
        print('Total time taken for Patch2Self: ', t2-t1, " seconds")

    if data_b0s.ndim == 3:
        denoised_arr[:, :, :, b0_idx[0][0]] = denoised_b0s
    else:
        for i, idx in enumerate(b0_idx):
            denoised_arr[:, :, :, idx[0]] = np.squeeze(denoised_b0s[..., i])

    for i, idx in enumerate(dwi_idx):
        denoised_arr[:, :, :, idx[0]] = np.squeeze(denoised_dwi[..., i])

    # clip out the negative values from the denoised output
    denoised_arr.clip(min=0, out=denoised_arr)

    return np.array(denoised_arr, dtype=out_dtype), coef_list

# %%
from numpy import mean

_, coefs_ols_list = patch2self(data, bval, verbose=True, model='ols', 
                               patch_radius=[0, 0, 0],
                               b0_threshold=50, sketch_size=i)
# coefs_ols = mean(coefs_ols_list)
# Out:
# Denoised DWI Volume:  60
# Total time taken for Patch2Self:  24.77943468093872  seconds

# %%
import scipy
from numpy import mean

list_acc = []
for i in range(0, len(list_sketch_size)*50):
    diff = scipy.linalg.norm(np.array(coefs_ols_list)-
                             np.array(coef_list[i]), ord=2) / scipy.linalg.norm(np.array(coefs_ols_list), ord=2)
    list_acc.append(diff)
    
from sklearn.preprocessing import minmax_scale

rel_err = minmax_scale(np.array(list_acc), feature_range=(0,1))

# %%
sketch_name_list = ['Randomized Leverage Scores' if x=='Leverage Scores: Exact' else x for x in sketch_name_list]

# %%
list_sketch_size_str = list(np.concatenate((np.repeat('0.5k', 5), np.repeat('1K', 5), np.repeat('5K', 5), 
                            np.repeat('10K', 5), np.repeat('20K', 5), np.repeat('30K', 5), np.repeat('40K', 5),
                            np.repeat('50K', 5), np.repeat('60K', 5), np.repeat('70K', 5), np.repeat('80K', 5),
                            np.repeat('100K', 5))))

list_sketch_size_str = list_sketch_size_str*10

# %%
len(list_sketch_size_str)
# Out:
# 600

# %%
import pandas as pd

df_diff = pd.DataFrame({'Error':rel_err,
                        'Sketching Dimension':list_sketch_size_str,
                        'Sketching Method':sketch_name_list})

# %%
# %matplotlib qt
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

ax = sns.pointplot(data=df_diff, x='Sketching Dimension', y='Error', hue='Sketching Method', 
                   palette="Set2", ci=95, markers=['*', 's', 'o', 'x', 'D', '^', 'X', 'd'], 
                   linestyles=['-', '-', '-', '-', '-', '-', '-', '-', '-'], scale=.8, join=True, )

# %%
# %matplotlib qt
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='white')

ax = sns.lineplot(data=df_diff, x='Sketching Dimension', y='Error', hue='Sketching Method', 
                  ci='sd', size_order='Error', sort=False, markers=True, style='Sketching Method')
figure = ax.get_figure()    
figure.savefig('errors_sketching.png', dpi=1000)

# %%
import pickle

f = open("dict_p2s_err_plot.pkl","wb")
pickle.dump(df_diff,f)
f.close()

# %%
import pandas as pd

object = pd.read_pickle(r'dict_p2s_err_plot.pkl')
